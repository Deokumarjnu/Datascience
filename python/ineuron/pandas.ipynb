# %%
# import pandas - liabrary
import pandas as pd

# %%
df = pd.read_csv("ex1.csv")

# %%
# show first 5 rows
df.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# show last 2 rows
df.tail(2)
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# Read TSV (tab sep value) file
df = pd.read_table("./test.tsv")
df.head()
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
# reading tsv file using read_csv
df = pd.read_csv("./test.tsv", sep="\t")
df.head()
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
# if you want to consider first row as data not header 
df = pd.read_csv("ex1.csv", header=None)
df.head()
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# overide column names or give column name as your wish
data = pd.read_csv("./ex2.csv", names=["first","sec","third","fourth","fifth"])
data.head()
# Out:
#    first  sec  third  fourth  fifth
# 0      1    2      3       4  hello
# 1      5    6      7       8  world
# 2      9   10     11      12    foo

# %%
data = pd.read_csv("./csv_mindex.csv")
data
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
# Lets do a multi level indexing , in above data we can see that a - 2, b - 2, c - 2 and d - 2 similarly we have one - 4, two -4
data = pd.read_csv("./csv_mindex.csv", index_col=["key1", "key2"])
data
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
#remove unwnated data from dataframe
df = pd.read_csv("./ex4.csv")
df
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
# on above data we can see the 0th , 2th and 3rd position data is not in redable form so will remove that
df = pd.read_csv("./ex4.csv", skiprows=[0,2,3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# Will handle NAN values while reading the file
data = pd.read_csv("./ex5.csv")
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# let check for null in data
data = pd.read_csv("./ex5.csv")
# data.isnull()
# or
pd.isnull(data)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
# we can count the null values of particular column sum()
# data.isnull().sum()
# or
pd.isnull(data).sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
# Read excel file
data = pd.read_excel("ex1.xlsx")
data
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
# Read excel file with sheetname
data = pd.read_excel("ex1.xlsx", sheet_name="Sheet1")
data
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
# read data from html page/ website
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"

BB_data = pd.read_html(url)         # Read data from the specified url

BB_data[0]

# %%
pd.options.display.max_rows = 10
# OR
pd.read_csv("./ex6.csv", nrows=10)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# 5  1.817480  0.742273  0.419395 -2.251035   Q
# 6 -0.776764  0.935518 -0.332872 -1.875641   U
# 7 -0.913135  1.530624 -0.572657  0.477252   K
# 8  0.358480 -0.497572 -0.367016  0.507702   S
# 9 -1.740877 -1.160417 -1.637830  2.172201   G

# %%
chunk = pd.read_csv("./ex6.csv", chunksize=20)

# %%
chunk

# %%
print(pd.DataFrame(chunk))
# Out:
# Empty DataFrame
# Columns: []
# Index: []
